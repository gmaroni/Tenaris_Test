# 9556  33.41  77.95  1010.30000  59.72  432.90
# 9557  15.99  43.34  1014.20000  78.66  465.96
# 9558  17.65  59.87  1018.58000  94.65  450.93
# 9559  23.68  51.30  1011.86000  71.24  451.67
#
# [9560 rows x 5 columns]

# %% [markdown]
# Vi sono una miriade di approcci per calcolare l'importanza di una features rispetto al loro potere predittivo della target, sopra è stata usata la correlazione tra le singole features e la target che ci da una indicazione di relazione lineare tra input e target, di conseguenza se utilizzaimo un modello lineare per modellizzare i dati sappiamo già che le variabili più importanti saranno le variabili at al primo posto e la variabile v al secondo posto.

# %% [markdown]
# Altri possibili approcci sono i seguenti

# %% [markdown]
# ## Informazione mutua

# %%
from sklearn.feature_selection import mutual_info_classif, mutual_info_regression

# %% [markdown]
# Mutual information measures how much information the presence/absence of a feature contributes to making the correct prediction on Y.
#
# As extracted from [wikipedia](https://en.wikipedia.org/wiki/Mutual_information):
#
# Mutual information measures the information that X and Y share: It measures how much knowing one of these variables reduces uncertainty about the other. For example, if X and Y are independent, then knowing X does not give any information about Y and vice versa, so their mutual information is zero. At the other extreme, if X is a deterministic function of Y and Y is a deterministic function of X then all information conveyed by X is shared with Y: knowing X determines the value of Y and vice versa. As a result, in this case the mutual information is the same as the uncertainty contained in Y (or X) alone, namely the entropy of Y (or X). Moreover, this mutual information is the same as the entropy of X and as the entropy of Y. (A very special case of this is when X and Y are the same random variable.)

# %%
y = df.pe.copy()
X = df.drop('pe',1).copy()

# %%
# determine the mutual information
mi = mutual_info_regression(X, y)
mi = pd.Series(mi)
mi.index = X.columns
mi.sort_values(ascending=False)
# Out:
# at    1.168260
# v     0.948890
# ap    0.280836
# rh    0.119641
# dtype: float64

# %%
mi.sort_values(ascending=False).plot.bar(figsize=(20,8), fontsize=16)

# %% [markdown]
# ## F regression

# %%
from sklearn.feature_selection import f_regression

# %%
univariate = f_regression(X, y)
univariate = pd.Series(univariate[0])
univariate.index = X.columns
univariate.sort_values(ascending=False, inplace=True)

# %%
univariate.sort_values(ascending=False).plot.bar(figsize=(20,8), fontsize=16)

# %% [markdown]
# ## Target binning

# %% [markdown]
# Adesso implemento un metodo utilizzato nella competizione KDD 2019 utilizzata dai data scientist dell'università di melbourne vincitori di tale competizione

# %%
def KDD_feat_imp(df, var, target, n_bins=100):
    
    labels = ['Q' + str(i + 1) for i in range(0, n_bins)]

    df[f'{var}_binned'], intervals = pd.qcut(
        df[var],
        n_bins,
        labels=labels,
        retbins=True,
        precision=3,
        duplicates='drop')
    
    risk_dict = df.groupby([f'{var}_binned'])[target].mean().to_dict()

    df[f'{var}_binned'] = df[f'{var}_binned'].map(risk_dict)
    return df

# %%
from sklearn.metrics import r2_score

df2 = KDD_feat_imp(df, 'at', 'pe', n_bins=100)

r2_score(df.pe, df2['at_binned'])
# Out:
# 0.9129398597028121

# %%
df2 = KDD_feat_imp(df, 'v', 'pe', n_bins=100)

r2_score(df.pe, df2['v_binned'])
# Out:
# 0.8186140181674593

# %%
df2 = KDD_feat_imp(df, 'ap', 'pe', n_bins=100)

r2_score(df.pe, df2['ap_binned'])
# Out:
# 0.31381772208332437

# %%
df2 = KDD_feat_imp(df, 'rh', 'pe', n_bins=100)

r2_score(df.pe, df2['rh_binned'])
# Out:
# 0.16278619846306175

# %% [markdown]
# ## Lasso regression

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Lasso

def cv_optimize_lasso(X, y, list_of_lambdas, n_folds=4):
    clf = Lasso(normalize=True)
    parameters = {"alpha": list_of_lambdas}
    gs = GridSearchCV(clf, param_grid=parameters, cv=n_folds, scoring="neg_mean_squared_error")
    gs.fit(X, y)
    return gs

# %%
lol = [1e-8,1e-6, 1e-5, 5e-5, 1e-4, 5e-4, 1e-3, 1e-2, 1e-1, 1.0, 10.0]

fitmodel_lasso = cv_optimize_lasso(X, y, lol, n_folds=4)

# %%
lambdawechoose_lasso = fitmodel_lasso.best_params_['alpha']

est_lasso = Lasso(alpha=lambdawechoose_lasso, normalize=True).fit(X,y)
est_lasso
# Out:
# Lasso(alpha=1e-05, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=True, positive=False, precompute=False, random_state=None,
#    selection='cyclic', tol=0.0001, warm_start=False)

# %%
def nonzero_lasso(est, lcols):
    featuremask=(est.coef_ !=0.0)
    return pd.DataFrame(dict(feature=lcols, coef=est.coef_, 
        abscoef=np.abs(est.coef_)))[featuremask].sort_values('abscoef',ascending=False)

# %%
d=3

lasso_importances=nonzero_lasso(est_lasso, list(range(d+1)))
lasso_importances.set_index("feature", inplace=True)
lasso_importances
# Out:
#              coef   abscoef
# feature
# 0       -1.979623  1.979623
# 1       -0.234337  0.234337
# 3       -0.157993  0.157993
# 2        0.061342  0.061342

# %% [markdown]
# #### Tutti i metodi confermano il medesimo risultato e confermano le ipotesi fatte durante la fase di analisi esplorativa

# %% [markdown]
# ## Feature importance non lineare

# %% [markdown]
# Tutti i metodi di cui sopra sono utili nel caso in cui si assume che vi sia una dipendenza lineare tra target e features. Nei casi reali però si osservano spesso relazioni non lineari tra features e target che non sono in gradi di essere apprezzate dai metodi usati sopra.
#
# Per scoprire eventuali relaziono non lineari tra features e target vi sono diversi modi.
#
# Il modo più immediato è quello di trasformare con trasformazioni non lineari le features e poi utilizzare i metodi usati sopra.
#
# Un altro metodo è quello di utilizzare dei modelli di ml non lineari come per esempio metodi basati su alberi e utilzzare le tecniche di feature importance basate sul potere predittivo delle singole features rispetto alla target

# %%
df = pd.read_csv('data/data01.csv', low_memory=False, index_col=0)
df
# Out:
#          at      v       ap     rh      pe
# 0      8.34  40.77  1010.84  90.01  480.48
# 1     29.74  56.90  1007.15  41.91  438.76
# 2     19.07  49.69  1007.22  76.79  453.09
# 3     11.80  40.66  1017.13  97.20  464.43
# 4     13.97  39.16  1016.05  84.60  470.96
# 5     22.10  71.29  1008.20  75.38  442.35
# 6     14.47  41.76  1021.98  78.41  464.00
# 7     31.25  69.51  1010.25  36.83  428.77
# 8      6.77  38.18  1017.80  81.13  484.31
# 9     28.28  68.67  1006.36  69.90  435.29
# 10    22.99  46.93  1014.15  49.42  451.41
# 11    29.30  70.04  1010.95  61.23  426.25
# 12     8.14  37.49  1009.04  80.33  480.66
# 13    16.92  44.60  1017.34  58.75  460.17
# 14    22.72  64.15  1021.14  60.34  453.13
# 15    18.14  43.56  1012.83  47.10  461.71
# 16    11.49  44.63  1020.44  86.04  471.08
# 17     9.94  40.46  1018.90  68.51  473.74
# 18    23.54  41.10  1002.05  38.05  448.56
# 19    14.90  52.05  1015.11  77.33  464.82
# 20    33.80  64.96  1004.88  49.37  427.28
# 21    25.37  68.31  1011.12  70.99  441.76
# 22     7.29  41.04  1024.06  89.19  474.71
# 23    13.55  40.71  1019.13  75.44  467.21
# 24     6.39  35.57  1025.53  77.23  487.69
# 25    26.64  62.44  1011.81  72.46  438.67
# 26     7.84  41.39  1018.21  91.92  485.66
# 27    21.82  58.66  1011.71  64.37  452.16
# 28    27.17  67.45  1015.67  49.03  429.87
# 29    13.42  41.23   994.17  95.79  468.82
# ...     ...    ...      ...    ...     ...
# 9530   7.11  43.13  1018.96  87.82  486.11
# 9531  21.54  58.12  1015.33  78.67  454.32
# 9532  29.45  64.96  1005.52  59.92  433.04
# 9533  31.85  68.30  1014.76  47.06  428.72
# 9534  27.30  65.12  1016.24  44.87  442.78
# 9535  13.51  39.31  1012.18  75.19  466.46
# 9536  16.73  39.64  1008.94  74.91  464.46
# 9537  25.45  69.59  1008.51  83.17  445.61
# 9538  12.88  44.34  1016.03  88.51  474.94
# 9539  22.29  43.79  1015.68  41.75  461.23
# 9540  12.07  40.81  1025.63  68.02  475.96
# 9541  18.21  62.26  1011.97  87.28  455.88
# 9542  17.53  42.24  1016.90  60.95  470.63
# 9543  23.66  61.86  1013.33  83.09  444.27
# 9544  14.18  40.69  1014.73  74.88  471.52
# 9545  13.85  41.39  1018.62  75.55  471.45
# 9546  10.06  37.83  1005.49  99.46  473.51
# 9547  26.89  70.32  1012.39  87.17  435.56
# 9548   7.72  41.14  1025.11  96.75  478.34
# 9549  27.06  43.77  1011.02  42.61  442.15
# 9550  20.18  43.56  1013.14  39.16  462.80
# 9551  18.51  50.90  1012.95  82.71  459.11
# 9552  13.60  39.82  1013.34  86.10  470.69
# 9553  33.42  68.51  1011.91  45.83  427.66
# 9554  13.79  42.07  1018.27  88.06  462.25
# 9555  15.12  48.92  1011.80  72.93  462.59
# 9556  33.41  77.95  1010.30  59.72  432.90
# 9557  15.99  43.34  1014.20  78.66  465.96
# 9558  17.65  59.87  1018.58  94.65  450.93
# 9559  23.68  51.30  1011.86  71.24  451.67
#
# [9560 rows x 5 columns]

# %%
y = df.pe.copy()
X = df.drop('pe',1).copy()

# %%
from sklearn.preprocessing import PolynomialFeatures

poly = PolynomialFeatures(3)
X_poly = poly.fit_transform(X)

# %%
df_poly = pd.DataFrame(X_poly,columns=poly.get_feature_names(df.columns))

# %%
plt.figure(figsize=(20,20))
ax=sns.heatmap(df_poly.corr(), annot=True, fmt=".2f")

# %%
# determine the mutual information
mi = mutual_info_regression(df_poly, y)
mi = pd.Series(mi)
mi.index = df_poly.columns
mi.sort_values(ascending=False)
# Out:
# at^2 v      1.264482
# at v        1.245407
# at v ap     1.237262
# at v^2      1.197983
# at^2 ap     1.176581
# at^2        1.175558
# at^3        1.172394
# at          1.168328
# at^2 rh     1.164917
# at ap       1.163453
# at ap^2     1.155116
# at v rh     0.969678
# v           0.950385
# v^2         0.948809
# v^3         0.941296
# v ap        0.939126
# v^2 ap      0.935082
# v ap^2      0.893655
# at rh       0.785738
# at ap rh    0.783377
# v^2 rh      0.499831
# at rh^2     0.330285
# ap          0.282323
# ap^3        0.282282
# ap^2        0.282264
# v rh        0.253567
# v ap rh     0.249534
# ap^2 rh     0.128432
# v rh^2      0.126579
# rh^3        0.123946
# rh^2        0.120384
# rh          0.119855
# ap rh^2     0.115543
# ap rh       0.112870
# 1           0.000029
# dtype: float64

# %%
mi.sort_values(ascending=False).plot.bar(figsize=(20,8), fontsize=16)

# %%
univariate = f_regression(df_poly, y)
univariate = pd.Series(univariate[0])
univariate.index = df_poly.columns
univariate.sort_values(ascending=False, inplace=True)
# Out:
# C:\Users\gabri_lavoro\Anaconda3\envs\tenaris\lib\site-packages\sklearn\feature_selection\univariate_selection.py:299: RuntimeWarning: divide by zero encountered in true_divide
#   corr /= X_norms
# C:\Users\gabri_lavoro\Anaconda3\envs\tenaris\lib\site-packages\sklearn\feature_selection\univariate_selection.py:304: RuntimeWarning: invalid value encountered in true_divide
#   F = corr ** 2 / (1 - corr ** 2) * degrees_of_freedom
# C:\Users\gabri_lavoro\Anaconda3\envs\tenaris\lib\site-packages\scipy\stats\_distn_infrastructure.py:877: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Users\gabri_lavoro\Anaconda3\envs\tenaris\lib\site-packages\scipy\stats\_distn_infrastructure.py:877: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Users\gabri_lavoro\Anaconda3\envs\tenaris\lib\site-packages\scipy\stats\_distn_infrastructure.py:1831: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)

# %%
univariate.sort_values(ascending=False).plot.bar(figsize=(20,8), fontsize=16)

# %% [markdown]
# ## Metodo di ricerca esaustivo basato su random forest

# %% [markdown]
# Un ultimo modo per calcolare l'importanza delle features è selezionare un modello come per esempio un Random Forest, una metrica di valutazione come per esempio la metrica r2 e calcolare l'importanza predittiva delle features allenando il RF con una features singola alla volta e osservare con quale features si ottiene il massimo del potere predittivo della target

# %%
from mlxtend.feature_selection import ExhaustiveFeatureSelector as EFS
from sklearn.ensemble import RandomForestRegressor
import warnings
warnings.filterwarnings('ignore')

efs1 = EFS(RandomForestRegressor(n_jobs=4), 
           min_features=1,
           max_features=1, 
           scoring='r2',
           print_progress=True,
           cv=2)

efs1 = efs1.fit(X, y)
# Out:
# Features: 4/4

# %%
efs1.best_idx_
# Out:
# (1,)

# %%
efs1.best_score_
# Out:
# 0.9051461658446197

# %%
efs1.best_feature_names_
# Out:
# ('v',)

# %% [markdown]
# In questo caso, a differenza dei casi precedenti la features più predittiva sembra essere la variabile v.
#
# Occorre però prestare attenzione a questo risultato, in quanto questa metodologia è basata sul modello e sulla metrica scelti, cambiando modello e cambiando metrica si possono ottenere risultati differenti

# %%
efs1 = EFS(RandomForestRegressor(n_jobs=4), 
           min_features=1,
           max_features=2, 
           scoring='r2',
           print_progress=True,
           cv=2)

efs1 = efs1.fit(X, y)
# Out:
# Features: 10/10

# %%
efs1.best_feature_names_, efs1.best_score_
# Out:
# (('at', 'v'), 0.9431551110904675)

# %%
efs1 = EFS(RandomForestRegressor(n_jobs=4), 
           min_features=1,
           max_features=3, 
           scoring='r2',
           print_progress=True,
           cv=2)

efs1 = efs1.fit(X, y)
# Out:
# Features: 14/14

# %%
efs1.best_feature_names_, efs1.best_score_
# Out:
# (('at', 'v', 'ap'), 0.949800764062196)

# %%
efs1 = EFS(RandomForestRegressor(n_jobs=4), 
           min_features=1,
           max_features=4, 
           scoring='r2',
           print_progress=True,
           cv=2)

efs1 = efs1.fit(X, y)
# Out:
# Features: 15/15

# %%
efs1.best_feature_names_, efs1.best_score_
# Out:
# (('at', 'v', 'ap', 'rh'), 0.9522738968951516)

# %% [markdown]
# Le features ap ed rh sono considerate meno importanti dal RF, però tuttavia dimostrano potere predittivo dal momento che utilizzare tutte e 4 le features da il risultato migliore in termini di metrica r2

# %% [markdown]
# ## Considerazioni finali

# %% [markdown]
# #### L'importanza di una feature e il suo potere predittivo dipendono da tutta una serie di assunzioni, in primo luogo la relazione ce si sta cercando nei dati (lineare/nonlineare), il modello che si vuole utilizzare per fittare i dati e la metrica che si vuole ottimizzare.
#
# #### Da questo notebook risulta evidente che la feature at e a seguire la feature v sono le features più correlate linearmente con la target, sono di conseguenza quelle più informative se si vuole utilizare un modello lineare.
#
# #### Anche utilizzando un modello nonlineare la coppia di features at e v risulta quella più informativa
